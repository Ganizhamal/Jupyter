# %%
import requests
import xmltodict

url = "http://www.cbr.ru/scripts/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="05.04.2024" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>60,8018</Value><VunitRate>60,8018</VunitRate></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>54,2975</Value><VunitRate>54,2975</VunitRate></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>116,4807</Value><VunitRate>116,4807</VunitRate></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>23,7540</Value><VunitRate>0,23754</VunitRate></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>28,3608</Value><VunitRate>28,3608</VunitRate></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>50,8906</Value><VunitRate>50,8906</VunitRate></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>18,1987</Value><VunitRate>18,1987</VunitRate></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>25,6035</Value><VunitRate>0,256035</VunitRate></Valute><Valute ID="R01150"><NumCode>704</NumCode><CharCode>VND</CharCode><Nominal>10000</Nominal><Name>\xc2\xfc\xe5\xf2\xed\xe0\xec\xf1\xea\xe8\xf5 \xe4\xee\xed\xe3\xee\xe2</Name><Value>38,4000</Value><VunitRate>0,00384</VunitRate></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>11,8114</Value><VunitRate>11,8114</VunitRate></Valute><Valute ID="R01210"><NumCode>981</NumCode><CharCode>GEL</CharCode><Nominal>1</Nominal><Name>\xc3\xf0\xf3\xe7\xe8\xed\xf1\xea\xe8\xe9 \xeb\xe0\xf0\xe8</Name><Value>34,3911</Value><VunitRate>34,3911</VunitRate></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>13,3442</Value><VunitRate>13,3442</VunitRate></Valute><Valute ID="R01230"><NumCode>784</NumCode><CharCode>AED</CharCode><Nominal>1</Nominal><Name>\xc4\xe8\xf0\xf5\xe0\xec \xce\xc0\xdd</Name><Value>25,1343</Value><VunitRate>25,1343</VunitRate></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>92,3058</Value><VunitRate>92,3058</VunitRate></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>100,0668</Value><VunitRate>100,0668</VunitRate></Valute><Valute ID="R01240"><NumCode>818</NumCode><CharCode>EGP</CharCode><Nominal>10</Nominal><Name>\xc5\xe3\xe8\xef\xe5\xf2\xf1\xea\xe8\xf5 \xf4\xf3\xed\xf2\xee\xe2</Name><Value>19,4825</Value><VunitRate>1,94825</VunitRate></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>11,0615</Value><VunitRate>1,10615</VunitRate></Valute><Valute ID="R01280"><NumCode>360</NumCode><CharCode>IDR</CharCode><Nominal>10000 ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'ValCurs': {'@Date': '05.04.2024',
#   '@name': 'Foreign Currency Market',
#   'Valute': [{'@ID': 'R01010',
#     'NumCode': '036',
#     'CharCode': 'AUD',
#     'Nominal': '1',
#     'Name': 'Австралийский доллар',
#     'Value': '60,8018',
#     'VunitRate': '60,8018'},
#    {'@ID': 'R01020A',
#     'NumCode': '944',
#     'CharCode': 'AZN',
#     'Nominal': '1',
#     'Name': 'Азербайджанский манат',
#     'Value': '54,2975',
#     'VunitRate': '54,2975'},
#    {'@ID': 'R01035',
#     'NumCode': '826',
#     'CharCode': 'GBP',
#     'Nominal': '1',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'Value': '116,4807',
#     'VunitRate': '116,4807'},
#    {'@ID': 'R01060',
#     'NumCode': '051',
#     'CharCode': 'AMD',
#     'Nominal': '100',
#     'Name': 'Армянских драмов',
#     'Value': '23,7540',
#     'VunitRate': '0,23754'},
#    {'@ID': 'R01090B',
#     'NumCode': '933',
#     'CharCode': 'BYN',
#     'Nominal': '1',
#     'Name': 'Белорусский рубль',
#     'Value': '28,3608',
#     'VunitRate': '28,3608'},
#    {'@ID': 'R01100',
#     'NumCode': '975',
#     'CharCode': 'BGN',
#     'Nominal': '1',
#     'Name': 'Болгарский лев',
#     'Value': '50,8906',
#     'VunitRate': '50,8906'},
#    {'@ID': 'R01115',
#     'NumCode': '986',
#     'CharCode': 'BRL',
#     'Nominal': '1',
#     'Name': 'Бразильский реал',
#     'Value': '18,1987',
#     'VunitRate': '18,1987'},
#    {'@ID': 'R01135',
#     'NumCode': '348',
#     'CharCode': 'HUF',
#     'Nominal': '100',
#     'Name': 'Венгерских форинтов',
#     'Value': '25,6035',
#     'VunitRate': '0,256035'},
#    {'@ID': 'R01150',
#     'NumCode': '704',
#     'CharCode': 'VND',
#     'Nominal': '10000',
#     'Name': 'Вьетнамских донгов',
#     'Value': '38,4000',
#     'VunitRate': '0,00384'},
#    {'@ID': 'R01200',
#     'NumCode': '344',
#     'CharCode': 'HKD',
#     'Nominal': '1',
#     'Name': 'Гонконгский доллар',
#     'Value': '11,8114',
#     'VunitRate': '11,8114'},
#    {'@ID': 'R01210',
#     'NumCode': '981',
#     'CharCode': 'GEL',
#     'Nominal': '1',
#     'Name': 'Грузинский лари',
#     'Value': '34,3911',
#     'VunitRate': '34,3911'},
#    {'@ID': 'R01215',
#     'NumCode': '208',
#     'CharCode': 'DKK',
#     'Nominal': '1',
#     'Name': 'Датская крона',
#     'Value': '13,3442',
#     'VunitRate': '13,3442'},
#    {'@ID': 'R01230',
#     'NumCode': '784',
#     'CharCode': 'AED',
#     'Nominal': '1',
#     'Name': 'Дирхам ОАЭ',
#     'Value': '25,1343',
#     'VunitRate': '25,1343'},
#    {'@ID': 'R01235',
#     'NumCode': '840',
#     'CharCode': 'USD',
#     'Nominal': '1',
#     'Name': 'Доллар США',
#     'Value': '92,3058',
#     'VunitRate': '92,3058'},
#    {'@ID': 'R01239',
#     'NumCode': '978',
#     'CharCode': 'EUR',
#     'Nominal': '1',
#     'Name': 'Евро',
#     'Value': '100,0668',
#     'VunitRate': '100,0668'},
#    {'@ID': 'R01240',
#     'NumCode': '818',
#     'CharCode': 'EGP',
#     'Nominal': '10',
#     'Name': 'Египетских фунтов',
#     'Value': '19,4825',
#     'VunitRate': '1,94825'},
#    {'@ID': 'R01270',
#     'NumCode': '356',
#     'CharCode': 'INR',
#     'Nominal': '10',
#     'Name': 'Индийских рупий',
#     'Value': '11,0615',
#     'VunitRate': '1,10615'},
#    {'@ID': 'R01280',
#     'NumCode': '360',
#     'CharCode': 'IDR',
#     'Nominal': '10000',
#     'Name': 'Индонезийских рупий',
#     'Value': '57,9701',
#     'VunitRate': '0,00579701'},
#    {'@ID': 'R01335',
#     'NumCode': '398',
#     'CharCode': 'KZT',
#     'Nominal': '100',
#     'Name': 'Казахстанских тенге',
#     'Value': '20,6542',
#     'VunitRate': '0,206542'},
#    {'@ID': 'R01350',
#     'NumCode': '124',
#     'CharCode': 'CAD',
#     'Nominal': '1',
#     'Name': 'Канадский доллар',
#     'Value': '68,1878',
#     'VunitRate': '68,1878'},
#    {'@ID': 'R01355',
#     'NumCode': '634',
#     'CharCode': 'QAR',
#     'Nominal': '1',
#     'Name': 'Катарский риал',
#     'Value': '25,3587',
#     'VunitRate': '25,3587'},
#    {'@ID': 'R01370',
#     'NumCode': '417',
#     'CharCode': 'KGS',
#     'Nominal': '10',
#     'Name': 'Киргизских сомов',
#     'Value': '10,3308',
#     'VunitRate': '1,03308'},
#    {'@ID': 'R01375',
#     'NumCode': '156',
#     'CharCode': 'CNY',
#     'Nominal': '1',
#     'Name': 'Китайский юань',
#     'Value': '12,7143',
#     'VunitRate': '12,7143'},
#    {'@ID': 'R01500',
#     'NumCode': '498',
#     'CharCode': 'MDL',
#     'Nominal': '10',
#     'Name': 'Молдавских леев',
#     'Value': '52,0431',
#     'VunitRate': '5,20431'},
#    {'@ID': 'R01530',
#     'NumCode': '554',
#     'CharCode': 'NZD',
#     'Nominal': '1',
#     'Name': 'Новозеландский доллар',
#     'Value': '55,6050',
#     'VunitRate': '55,605'},
#    {'@ID': 'R01535',
#     'NumCode': '578',
#     'CharCode': 'NOK',
#     'Nominal': '10',
#     'Name': 'Норвежских крон',
#     'Value': '85,3774',
#     'VunitRate': '8,53774'},
#    {'@ID': 'R01565',
#     'NumCode': '985',
#     'CharCode': 'PLN',
#     'Nominal': '1',
#     'Name': 'Польский злотый',
#     'Value': '23,3597',
#     'VunitRate': '23,3597'},
#    {'@ID': 'R01585F',
#     'NumCode': '946',
#     'CharCode': 'RON',
#     'Nominal': '1',
#     'Name': 'Румынский лей',
#     'Value': '20,1704',
#     'VunitRate': '20,1704'},
#    {'@ID': 'R01589',
#     'NumCode': '960',
#     'CharCode': 'XDR',
#     'Nominal': '1',
#     'Name': 'СДР (специальные права заимствования)',
#     'Value': '122,0957',
#     'VunitRate': '122,0957'},
#    {'@ID': 'R01625',
#     'NumCode': '702',
#     'CharCode': 'SGD',
#     'Nominal': '1',
#     'Name': 'Сингапурский доллар',
#     'Value': '68,4761',
#     'VunitRate': '68,4761'},
#    {'@ID': 'R01670',
#     'NumCode': '972',
#     'CharCode': 'TJS',
#     'Nominal': '10',
#     'Name': 'Таджикских сомони',
#     'Value': '84,2675',
#     'VunitRate': '8,42675'},
#    {'@ID': 'R01675',
#     'NumCode': '764',
#     'CharCode': 'THB',
#     'Nominal': '10',
#     'Name': 'Таиландских батов',
#     'Value': '25,1679',
#     'VunitRate': '2,51679'},
#    {'@ID': 'R01700J',
#     'NumCode': '949',
#     'CharCode': 'TRY',
#     'Nominal': '10',
#     'Name': 'Турецких лир',
#     'Value': '28,8744',
#     'VunitRate': '2,88744'},
#    {'@ID': 'R01710A',
#     'NumCode': '934',
#     'CharCode': 'TMT',
#     'Nominal': '1',
#     'Name': 'Новый туркменский манат',
#     'Value': '26,3731',
#     'VunitRate': '26,3731'},
#    {'@ID': 'R01717',
#     'NumCode': '860',
#     'CharCode': 'UZS',
#     'Nominal': '10000',
#     'Name': 'Узбекских сумов',
#     'Value': '72,8653',
#     'VunitRate': '0,00728653'},
#    {'@ID': 'R01720',
#     'NumCode': '980',
#     'CharCode': 'UAH',
#     'Nominal': '10',
#     'Name': 'Украинских гривен',
#     'Value': '23,5502',
#     'VunitRate': '2,35502'},
#    {'@ID': 'R01760',
#     'NumCode': '203',
#     'CharCode': 'CZK',
#     'Nominal': '10',
#     'Name': 'Чешских крон',
#     'Value': '39,5789',
#     'VunitRate': '3,95789'},
#    {'@ID': 'R01770',
#     'NumCode': '752',
#     'CharCode': 'SEK',
#     'Nominal': '10',
#     'Name': 'Шведских крон',
#     'Value': '85,9899',
#     'VunitRate': '8,59899'},
#    {'@ID': 'R01775',
#     'NumCode': '756',
#     'CharCode': 'CHF',
#     'Nominal': '1',
#     'Name': 'Швейцарский франк',
#     'Value': '101,9053',
#     'VunitRate': '101,9053'},
#    {'@ID': 'R01805F',
#     'NumCode': '941',
#     'CharCode': 'RSD',
#     'Nominal': '100',
#     'Name': 'Сербских динаров',
#     'Value': '85,4501',
#     'VunitRate': '0,854501'},
#    {'@ID': 'R01810',
#     'NumCode': '710',
#     'CharCode': 'ZAR',
#     'Nominal': '10',
#     'Name': 'Южноафриканских рэндов',
#     'Value': '49,5857',
#     'VunitRate': '4,95857'},
#    {'@ID': 'R01815',
#     'NumCode': '410',
#     'CharCode': 'KRW',
#     'Nominal': '1000',
#     'Name': 'Вон Республики Корея',
#     'Value': '68,5219',
#     'VunitRate': '0,0685219'},
#    {'@ID': 'R01820',
#     'NumCode': '392',
#     'CharCode': 'JPY',
#     'Nominal': '100',
#     'Name': 'Японских иен',
#     'Value': '60,8797',
#     'VunitRate': '0,608797'}]}}

# %%
items = []
for valute in data['ValCurs']['Valute']:
    items.append(valute)

items
# Out:
# [{'@ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': '1',
#   'Name': 'Австралийский доллар',
#   'Value': '60,8018',
#   'VunitRate': '60,8018'},
#  {'@ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': '1',
#   'Name': 'Азербайджанский манат',
#   'Value': '54,2975',
#   'VunitRate': '54,2975'},
#  {'@ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': '1',
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': '116,4807',
#   'VunitRate': '116,4807'},
#  {'@ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': '100',
#   'Name': 'Армянских драмов',
#   'Value': '23,7540',
#   'VunitRate': '0,23754'},
#  {'@ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': '1',
#   'Name': 'Белорусский рубль',
#   'Value': '28,3608',
#   'VunitRate': '28,3608'},
#  {'@ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': '1',
#   'Name': 'Болгарский лев',
#   'Value': '50,8906',
#   'VunitRate': '50,8906'},
#  {'@ID': 'R01115',
#   'NumCode': '986',
#   'CharCode': 'BRL',
#   'Nominal': '1',
#   'Name': 'Бразильский реал',
#   'Value': '18,1987',
#   'VunitRate': '18,1987'},
#  {'@ID': 'R01135',
#   'NumCode': '348',
#   'CharCode': 'HUF',
#   'Nominal': '100',
#   'Name': 'Венгерских форинтов',
#   'Value': '25,6035',
#   'VunitRate': '0,256035'},
#  {'@ID': 'R01150',
#   'NumCode': '704',
#   'CharCode': 'VND',
#   'Nominal': '10000',
#   'Name': 'Вьетнамских донгов',
#   'Value': '38,4000',
#   'VunitRate': '0,00384'},
#  {'@ID': 'R01200',
#   'NumCode': '344',
#   'CharCode': 'HKD',
#   'Nominal': '1',
#   'Name': 'Гонконгский доллар',
#   'Value': '11,8114',
#   'VunitRate': '11,8114'},
#  {'@ID': 'R01210',
#   'NumCode': '981',
#   'CharCode': 'GEL',
#   'Nominal': '1',
#   'Name': 'Грузинский лари',
#   'Value': '34,3911',
#   'VunitRate': '34,3911'},
#  {'@ID': 'R01215',
#   'NumCode': '208',
#   'CharCode': 'DKK',
#   'Nominal': '1',
#   'Name': 'Датская крона',
#   'Value': '13,3442',
#   'VunitRate': '13,3442'},
#  {'@ID': 'R01230',
#   'NumCode': '784',
#   'CharCode': 'AED',
#   'Nominal': '1',
#   'Name': 'Дирхам ОАЭ',
#   'Value': '25,1343',
#   'VunitRate': '25,1343'},
#  {'@ID': 'R01235',
#   'NumCode': '840',
#   'CharCode': 'USD',
#   'Nominal': '1',
#   'Name': 'Доллар США',
#   'Value': '92,3058',
#   'VunitRate': '92,3058'},
#  {'@ID': 'R01239',
#   'NumCode': '978',
#   'CharCode': 'EUR',
#   'Nominal': '1',
#   'Name': 'Евро',
#   'Value': '100,0668',
#   'VunitRate': '100,0668'},
#  {'@ID': 'R01240',
#   'NumCode': '818',
#   'CharCode': 'EGP',
#   'Nominal': '10',
#   'Name': 'Египетских фунтов',
#   'Value': '19,4825',
#   'VunitRate': '1,94825'},
#  {'@ID': 'R01270',
#   'NumCode': '356',
#   'CharCode': 'INR',
#   'Nominal': '10',
#   'Name': 'Индийских рупий',
#   'Value': '11,0615',
#   'VunitRate': '1,10615'},
#  {'@ID': 'R01280',
#   'NumCode': '360',
#   'CharCode': 'IDR',
#   'Nominal': '10000',
#   'Name': 'Индонезийских рупий',
#   'Value': '57,9701',
#   'VunitRate': '0,00579701'},
#  {'@ID': 'R01335',
#   'NumCode': '398',
#   'CharCode': 'KZT',
#   'Nominal': '100',
#   'Name': 'Казахстанских тенге',
#   'Value': '20,6542',
#   'VunitRate': '0,206542'},
#  {'@ID': 'R01350',
#   'NumCode': '124',
#   'CharCode': 'CAD',
#   'Nominal': '1',
#   'Name': 'Канадский доллар',
#   'Value': '68,1878',
#   'VunitRate': '68,1878'},
#  {'@ID': 'R01355',
#   'NumCode': '634',
#   'CharCode': 'QAR',
#   'Nominal': '1',
#   'Name': 'Катарский риал',
#   'Value': '25,3587',
#   'VunitRate': '25,3587'},
#  {'@ID': 'R01370',
#   'NumCode': '417',
#   'CharCode': 'KGS',
#   'Nominal': '10',
#   'Name': 'Киргизских сомов',
#   'Value': '10,3308',
#   'VunitRate': '1,03308'},
#  {'@ID': 'R01375',
#   'NumCode': '156',
#   'CharCode': 'CNY',
#   'Nominal': '1',
#   'Name': 'Китайский юань',
#   'Value': '12,7143',
#   'VunitRate': '12,7143'},
#  {'@ID': 'R01500',
#   'NumCode': '498',
#   'CharCode': 'MDL',
#   'Nominal': '10',
#   'Name': 'Молдавских леев',
#   'Value': '52,0431',
#   'VunitRate': '5,20431'},
#  {'@ID': 'R01530',
#   'NumCode': '554',
#   'CharCode': 'NZD',
#   'Nominal': '1',
#   'Name': 'Новозеландский доллар',
#   'Value': '55,6050',
#   'VunitRate': '55,605'},
#  {'@ID': 'R01535',
#   'NumCode': '578',
#   'CharCode': 'NOK',
#   'Nominal': '10',
#   'Name': 'Норвежских крон',
#   'Value': '85,3774',
#   'VunitRate': '8,53774'},
#  {'@ID': 'R01565',
#   'NumCode': '985',
#   'CharCode': 'PLN',
#   'Nominal': '1',
#   'Name': 'Польский злотый',
#   'Value': '23,3597',
#   'VunitRate': '23,3597'},
#  {'@ID': 'R01585F',
#   'NumCode': '946',
#   'CharCode': 'RON',
#   'Nominal': '1',
#   'Name': 'Румынский лей',
#   'Value': '20,1704',
#   'VunitRate': '20,1704'},
#  {'@ID': 'R01589',
#   'NumCode': '960',
#   'CharCode': 'XDR',
#   'Nominal': '1',
#   'Name': 'СДР (специальные права заимствования)',
#   'Value': '122,0957',
#   'VunitRate': '122,0957'},
#  {'@ID': 'R01625',
#   'NumCode': '702',
#   'CharCode': 'SGD',
#   'Nominal': '1',
#   'Name': 'Сингапурский доллар',
#   'Value': '68,4761',
#   'VunitRate': '68,4761'},
#  {'@ID': 'R01670',
#   'NumCode': '972',
#   'CharCode': 'TJS',
#   'Nominal': '10',
#   'Name': 'Таджикских сомони',
#   'Value': '84,2675',
#   'VunitRate': '8,42675'},
#  {'@ID': 'R01675',
#   'NumCode': '764',
#   'CharCode': 'THB',
#   'Nominal': '10',
#   'Name': 'Таиландских батов',
#   'Value': '25,1679',
#   'VunitRate': '2,51679'},
#  {'@ID': 'R01700J',
#   'NumCode': '949',
#   'CharCode': 'TRY',
#   'Nominal': '10',
#   'Name': 'Турецких лир',
#   'Value': '28,8744',
#   'VunitRate': '2,88744'},
#  {'@ID': 'R01710A',
#   'NumCode': '934',
#   'CharCode': 'TMT',
#   'Nominal': '1',
#   'Name': 'Новый туркменский манат',
#   'Value': '26,3731',
#   'VunitRate': '26,3731'},
#  {'@ID': 'R01717',
#   'NumCode': '860',
#   'CharCode': 'UZS',
#   'Nominal': '10000',
#   'Name': 'Узбекских сумов',
#   'Value': '72,8653',
#   'VunitRate': '0,00728653'},
#  {'@ID': 'R01720',
#   'NumCode': '980',
#   'CharCode': 'UAH',
#   'Nominal': '10',
#   'Name': 'Украинских гривен',
#   'Value': '23,5502',
#   'VunitRate': '2,35502'},
#  {'@ID': 'R01760',
#   'NumCode': '203',
#   'CharCode': 'CZK',
#   'Nominal': '10',
#   'Name': 'Чешских крон',
#   'Value': '39,5789',
#   'VunitRate': '3,95789'},
#  {'@ID': 'R01770',
#   'NumCode': '752',
#   'CharCode': 'SEK',
#   'Nominal': '10',
#   'Name': 'Шведских крон',
#   'Value': '85,9899',
#   'VunitRate': '8,59899'},
#  {'@ID': 'R01775',
#   'NumCode': '756',
#   'CharCode': 'CHF',
#   'Nominal': '1',
#   'Name': 'Швейцарский франк',
#   'Value': '101,9053',
#   'VunitRate': '101,9053'},
#  {'@ID': 'R01805F',
#   'NumCode': '941',
#   'CharCode': 'RSD',
#   'Nominal': '100',
#   'Name': 'Сербских динаров',
#   'Value': '85,4501',
#   'VunitRate': '0,854501'},
#  {'@ID': 'R01810',
#   'NumCode': '710',
#   'CharCode': 'ZAR',
#   'Nominal': '10',
#   'Name': 'Южноафриканских рэндов',
#   'Value': '49,5857',
#   'VunitRate': '4,95857'},
#  {'@ID': 'R01815',
#   'NumCode': '410',
#   'CharCode': 'KRW',
#   'Nominal': '1000',
#   'Name': 'Вон Республики Корея',
#   'Value': '68,5219',
#   'VunitRate': '0,0685219'},
#  {'@ID': 'R01820',
#   'NumCode': '392',
#   'CharCode': 'JPY',
#   'Nominal': '100',
#   'Name': 'Японских иен',
#   'Value': '60,8797',
#   'VunitRate': '0,608797'}]

# %%
my_array = []  

for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']]  
    my_array.append(my_set)  
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '60,8018']
# ['AZN', 'Азербайджанский манат', '54,2975']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '116,4807']
# ['AMD', 'Армянских драмов', '23,7540']
# ['BYN', 'Белорусский рубль', '28,3608']
# ['BGN', 'Болгарский лев', '50,8906']
# ['BRL', 'Бразильский реал', '18,1987']
# ['HUF', 'Венгерских форинтов', '25,6035']
# ['VND', 'Вьетнамских донгов', '38,4000']
# ['HKD', 'Гонконгский доллар', '11,8114']
# ['GEL', 'Грузинский лари', '34,3911']
# ['DKK', 'Датская крона', '13,3442']
# ['AED', 'Дирхам ОАЭ', '25,1343']
# ['USD', 'Доллар США', '92,3058']
# ['EUR', 'Евро', '100,0668']
# ['EGP', 'Египетских фунтов', '19,4825']
# ['INR', 'Индийских рупий', '11,0615']
# ['IDR', 'Индонезийских рупий', '57,9701']
# ['KZT', 'Казахстанских тенге', '20,6542']
# ['CAD', 'Канадский доллар', '68,1878']
# ['QAR', 'Катарский риал', '25,3587']
# ['KGS', 'Киргизских сомов', '10,3308']
# ['CNY', 'Китайский юань', '12,7143']
# ['MDL', 'Молдавских леев', '52,0431']
# ['NZD', 'Новозеландский доллар', '55,6050']
# ['NOK', 'Норвежских крон', '85,3774']
# ['PLN', 'Польский злотый', '23,3597']
# ['RON', 'Румынский лей', '20,1704']
# ['XDR', 'СДР (специальные права заимствования)', '122,0957']
# ['SGD', 'Сингапурский доллар', '68,4761']
# ['TJS', 'Таджикских сомони', '84,2675']
# ['THB', 'Таиландских батов', '25,1679']
# ['TRY', 'Турецких лир', '28,8744']
# ['TMT', 'Новый туркменский манат', '26,3731']
# ['UZS', 'Узбекских сумов', '72,8653']
# ['UAH', 'Украинских гривен', '23,5502']
# ['CZK', 'Чешских крон', '39,5789']
# ['SEK', 'Шведских крон', '85,9899']
# ['CHF', 'Швейцарский франк', '101,9053']
# ['RSD', 'Сербских динаров', '85,4501']
# ['ZAR', 'Южноафриканских рэндов', '49,5857']
# ['KRW', 'Вон Республики Корея', '68,5219']
# ['JPY', 'Японских иен', '60,8797']

# %%
 my_array
# Out:
# [['AUD', 'Австралийский доллар', '60,8018'],
#  ['AZN', 'Азербайджанский манат', '54,2975'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '116,4807'],
#  ['AMD', 'Армянских драмов', '23,7540'],
#  ['BYN', 'Белорусский рубль', '28,3608'],
#  ['BGN', 'Болгарский лев', '50,8906'],
#  ['BRL', 'Бразильский реал', '18,1987'],
#  ['HUF', 'Венгерских форинтов', '25,6035'],
#  ['VND', 'Вьетнамских донгов', '38,4000'],
#  ['HKD', 'Гонконгский доллар', '11,8114'],
#  ['GEL', 'Грузинский лари', '34,3911'],
#  ['DKK', 'Датская крона', '13,3442'],
#  ['AED', 'Дирхам ОАЭ', '25,1343'],
#  ['USD', 'Доллар США', '92,3058'],
#  ['EUR', 'Евро', '100,0668'],
#  ['EGP', 'Египетских фунтов', '19,4825'],
#  ['INR', 'Индийских рупий', '11,0615'],
#  ['IDR', 'Индонезийских рупий', '57,9701'],
#  ['KZT', 'Казахстанских тенге', '20,6542'],
#  ['CAD', 'Канадский доллар', '68,1878'],
#  ['QAR', 'Катарский риал', '25,3587'],
#  ['KGS', 'Киргизских сомов', '10,3308'],
#  ['CNY', 'Китайский юань', '12,7143'],
#  ['MDL', 'Молдавских леев', '52,0431'],
#  ['NZD', 'Новозеландский доллар', '55,6050'],
#  ['NOK', 'Норвежских крон', '85,3774'],
#  ['PLN', 'Польский злотый', '23,3597'],
#  ['RON', 'Румынский лей', '20,1704'],
#  ['XDR', 'СДР (специальные права заимствования)', '122,0957'],
#  ['SGD', 'Сингапурский доллар', '68,4761'],
#  ['TJS', 'Таджикских сомони', '84,2675'],
#  ['THB', 'Таиландских батов', '25,1679'],
#  ['TRY', 'Турецких лир', '28,8744'],
#  ['TMT', 'Новый туркменский манат', '26,3731'],
#  ['UZS', 'Узбекских сумов', '72,8653'],
#  ['UAH', 'Украинских гривен', '23,5502'],
#  ['CZK', 'Чешских крон', '39,5789'],
#  ['SEK', 'Шведских крон', '85,9899'],
#  ['CHF', 'Швейцарский франк', '101,9053'],
#  ['RSD', 'Сербских динаров', '85,4501'],
#  ['ZAR', 'Южноафриканских рэндов', '49,5857'],
#  ['KRW', 'Вон Республики Корея', '68,5219'],
#  ['JPY', 'Японских иен', '60,8797']]
